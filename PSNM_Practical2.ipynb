# %% [markdown]
# <h1 align="center"><strong>Vansh Shah - TIU2141050775</strong></h1>
#
# <h2 align="center"><em>PRACTICAL - 2</em></h2>
#
# <h3 align="center"><strong>Regula Falsi Method</strong></h3>

# %% [markdown]
# # **1**. x<sup>4</sup> − x = 10 correct till 3 decimal places. (Find both positive and negative root)

# %% [markdown]
# # **Negative Root**

# %%
def  f(x):
    return x**4-x-10;

def check():
    i=0;
    while (True):
        j=i-1;

        if ( f(i)*f(j) < 0 ):
            print(f"The root of the given function lies between {(i,j)}");
            function(i,j);
            break;

        else:
            i-=1;

def function(a,b):

    step=1;
    cond=True;
    while(cond):
        r=(a*f(b)-b*f(a))/(f(b)-f(a));
        print(f"Itration {step}: x= {round(r,pre)} and f(x) = {round(f(r),pre)} ")

        if f(r)==0:
            break;
        elif f(r)*f(a)<0:
            b=r;
        else:
            a=r;
        step+=1;
        cond=abs(f(r))>tolerance

    print(f"The value of root is : {round(r,pre)} after {step} Itration")
tolerance = float(input("Enter Tolerance Value:"))
pre = int(input("Enter d.p.: "))
check();
# Out:
# Enter Tolerance Value:0.0001
# Enter d.p.: 3
# The root of the given function lies between (-1, -2)
# Itration 1: x= -1.5 and f(x) = -3.438
# Itration 2: x= -1.65 and f(x) = -0.933
# Itration 3: x= -1.687 and f(x) = -0.218
# Itration 4: x= -1.695 and f(x) = -0.049
# Itration 5: x= -1.697 and f(x) = -0.011
# Itration 6: x= -1.697 and f(x) = -0.002
# Itration 7: x= -1.697 and f(x) = -0.001
# Itration 8: x= -1.697 and f(x) = -0.0
# Itration 9: x= -1.697 and f(x) = -0.0
# The value of root is : -1.697 after 10 Itration

# %% [markdown]
# # **Positive Root**

# %%
def  f(x):
    return x**4-x-10;

def check():
    i=0;
    while (True):
        j=i++1;

        if ( f(i)*f(j) < 0 ):
            print(f"The root of the given function lies between {(i,j)}");
            function(i,j);
            break;

        else:
            i+=1;

def function(a,b):

    step=1;
    cond=True;
    while(cond):
        r=(a*f(b)-b*f(a))/(f(b)-f(a));
        print(f"Itration {step}: x= {round(r,pre)} and f(x) = {round(f(r),pre)} ")

        if f(r)==0:
            break;
        elif f(r)*f(a)<0:
            b=r;
        else:
            a=r;
        step+=1;
        cond=abs(f(r))>tolerance

    print(f"The value of root is : {round(r,pre)} after {step} Itration")
tolerance = float(input("Enter Tolerance Value:"))
pre = int(input("Enter d.p.: "))
check();
# Out:
# Enter Tolerance Value:0.0001
# Enter d.p.: 3
# The root of the given function lies between (1, 2)
# Itration 1: x= 1.714 and f(x) = -3.078
# Itration 2: x= 1.839 and f(x) = -0.413
# Itration 3: x= 1.854 and f(x) = -0.048
# Itration 4: x= 1.855 and f(x) = -0.005
# Itration 5: x= 1.856 and f(x) = -0.001
# Itration 6: x= 1.856 and f(x) = -0.0
# The value of root is : 1.856 after 7 Itration

# %% [markdown]
# # **2**. x<sup>3</sup> + x − 1 = 0 correct till 5 decimal places. (positive root)

# %%
def  f(x):
    return x**3+x-1;

def check():
    i=0;
    while (True):
        j=i+1;

        if ( f(i)*f(j) < 0 ):
            print(f"The root of the given function lies between {(i,j)}");
            function(i,j);
            break;

        else:
            i+=1;

def function(a,b):

    step=1;
    cond=True;
    while(cond):
        r=(a*f(b)-b*f(a))/(f(b)-f(a));
        print(f"Itration {step}: x= {round(r,pre)} and f(x) = {round(f(r),pre)} ")

        if f(r)==0:
            break;
        elif f(r)*f(a)<0:
            b=r;
        else:
            a=r;
        step+=1;
        cond=abs(f(r))>tolerance

    print(f"The value of root is : {round(r,pre)} after {step} Itration")
tolerance = float(input("Enter Tolerance Value:"))
pre = int(input("Enter d.p.: "))
check();
# Out:
# Enter Tolerance Value:0.000001
# Enter d.p.: 5
# The root of the given function lies between (0, 1)
# Itration 1: x= 0.5 and f(x) = -0.375
# Itration 2: x= 0.63636 and f(x) = -0.10594
# Itration 3: x= 0.6712 and f(x) = -0.02643
# Itration 4: x= 0.67966 and f(x) = -0.00638
# Itration 5: x= 0.68169 and f(x) = -0.00153
# Itration 6: x= 0.68218 and f(x) = -0.00036
# Itration 7: x= 0.68229 and f(x) = -9e-05
# Itration 8: x= 0.68232 and f(x) = -2e-05
# Itration 9: x= 0.68233 and f(x) = -0.0
# Itration 10: x= 0.68233 and f(x) = -0.0
# Itration 11: x= 0.68233 and f(x) = -0.0
# The value of root is : 0.68233 after 12 Itration

# %% [markdown]
# # **3**. x<sup>3</sup> + x + 1 = 0 correct till 5 decimal places. (negative root)

# %%
def  f(x):
    return x**3+x+1;

def check():
    i=0;
    while (True):
        j=i-1;

        if ( f(i)*f(j) < 0 ):
            print(f"The root of the given function lies between {(i,j)}");
            function(i,j);
            break;

        else:
            i-=1;

def function(a,b):

    step=1;
    cond=True;
    while(cond):
        r=(a*f(b)-b*f(a))/(f(b)-f(a));
        print(f"Itration {step}: x= {round(r,pre)} and f(x) = {round(f(r),pre)} ");

        if f(r)==0:
            break;
        elif f(r)*f(a)<0:
            b=r;
        else:
            a=r;
        step+=1;
        cond=abs(f(r))>tolerance

    print(f"The value of root is : {round(r,pre)} after {step} Itration")
tolerance = float(input("Enter Tolerance Value:"))
pre = int(input("Enter d.p.: "))
check();
# Out:
# Enter Tolerance Value:0.000001
# Enter d.p.: 5
# The root of the given function lies between (0, -1)
# Itration 1: x= -0.5 and f(x) = 0.375
# Itration 2: x= -0.63636 and f(x) = 0.10594
# Itration 3: x= -0.6712 and f(x) = 0.02643
# Itration 4: x= -0.67966 and f(x) = 0.00638
# Itration 5: x= -0.68169 and f(x) = 0.00153
# Itration 6: x= -0.68218 and f(x) = 0.00036
# Itration 7: x= -0.68229 and f(x) = 9e-05
# Itration 8: x= -0.68232 and f(x) = 2e-05
# Itration 9: x= -0.68233 and f(x) = 0.0
# Itration 10: x= -0.68233 and f(x) = 0.0
# Itration 11: x= -0.68233 and f(x) = 0.0
# The value of root is : -0.68233 after 12 Itration

# %% [markdown]
# # **4**. X log<sub>10</sub> X = 4.5 correct till 4 decimal places.

# %%
import math

def  f(x):
    return ((math.log(x)/2.303)*x)-9/2;

def check():
    i=0.01;
    while (True):
        j=i+1;

        if ( f(i)*f(j) < 0 ):
            print(f"The root of the given function lies between {(i,j)}");
            function(i,j);
            break;

        else:
            i+=1;
def function(a,b):
    step=1;
    cond=True;
    while(cond):
        r=(a*f(b)-b*f(a))/(f(b)-f(a));
        print(f"Itration {step}: x= {round(r,pre)} and f(x) = {round(f(r),pre)} ");

        if f(r)==0:
            break;
        elif f(r)*f(a)<0:
            b=r;
        else:
            a=r;
        step+=1;
        cond=abs(f(r))>tolerance

    print(f"The value of root is : {round(r,pre)} after {step} Itration")
tolerance = float(input("Enter Tolerance Value:"))
pre = int(input("Enter d.p.: "))
check();
# Out:
# Enter Tolerance Value:0.00001
# Enter d.p.: 4
# The root of the given function lies between (5.01, 6.01)
# Itration 1: x= 5.8566 and f(x) = -0.005
# Itration 2: x= 5.8608 and f(x) = -0.0
# Itration 3: x= 5.8608 and f(x) = -0.0
# The value of root is : 5.8608 after 4 Itration

# %% [markdown]
# # **5**. xe<sup>x−3</sup> = 1 − x cos(x − 1). Perform 15 iterations.

# %%
import math

def  f(x):
    return x*(math.e**(x-3))-1+x*(math.cos(x-1));

def check():
    i=0;
    while (True):
        j=i-1;

        if ( f(i)*f(j) <0 ):
            print(f"The root of the given function lies between {(i,j)}");
            function(i,j);
            break;
        else:
            i-=1;
def function(a,b):
    step=1;
    while(step <= 15):
        r=(a*f(b)-b*f(a))/(f(b)-f(a));
        print(f"Itration {step}: x= {round(r,pre)} and f(x) = {round(f(r),pre)} ");

        if ( r<-6):
            break;
        elif f(r)*f(a)<0:
            b=r;
        else:
            a=r;
        step+=1;

    print(f"The value of root is : {round(r,pre)} after {step} Itration")
tolerance = float(input("Enter Tolerance Value:"))
pre = int(input("Enter d.p.: "))
check();
# Out:
# Enter Tolerance Value:0.00001
# Enter d.p.: 4
# The root of the given function lies between (-1, -2)
# Itration 1: x= -1.3839 and f(x) = -0.012
# Itration 2: x= -1.3914 and f(x) = 0.0007
# Itration 3: x= -1.391 and f(x) = -0.0
# Itration 4: x= -1.391 and f(x) = -0.0
# Itration 5: x= -1.391 and f(x) = -0.0
# Itration 6: x= -1.391 and f(x) = -0.0
# Itration 7: x= -1.391 and f(x) = -0.0
# Itration 8: x= -1.391 and f(x) = -0.0
# Itration 9: x= -1.391 and f(x) = -0.0
# Itration 10: x= -1.391 and f(x) = -0.0
# Itration 11: x= -1.391 and f(x) = -0.0
# Itration 12: x= -1.391 and f(x) = -0.0
# Itration 13: x= -1.391 and f(x) = -0.0
# Itration 14: x= -1.391 and f(x) = -0.0
# Itration 15: x= -1.391 and f(x) = -0.0
# The value of root is : -1.391 after 16 Itration

# %% [markdown]
# # **6**. (x + 1) cos x = 2x. Perform 12 iterations.

# %%
import math

def  f(x):
    return (x+1)*math.cos(x)-2*x;

def check():
    i=0;
    while (True):
        j=i+1;

        if ( f(i)*f(j) <0 ):
            print(f"The root of the given function lies between {(i,j)}");
            function(i,j);
            break;
        else:
            i+=1;
def function(a,b):
    step=1;
    count=1;
    while(step <=12):
        r=(a*f(b)-b*f(a))/(f(b)-f(a));
        print(f"Itration {step}: x= {round(r,pre)} and f(x) = {round(f(r),pre)} ");

        if f(r)==0:
            break;
        elif f(r)*f(a)<0:
            b=r;
        else:
            a=r;
        step+=1;

    print(f"The value of root is : {round(r,pre)} after {step} Itration")
tolerance = float(input("Enter Tolerance Value:"))
pre = int(input("Enter d.p.: "))
check();
# Out:
# Enter Tolerance Value:0.00001
# Enter d.p.: 4
# The root of the given function lies between (0, 1)
# Itration 1: x= 0.521 and f(x) = 0.2772
# Itration 2: x= 0.632 and f(x) = 0.0529
# Itration 3: x= 0.652 and f(x) = 0.0092
# Itration 4: x= 0.6554 and f(x) = 0.0016
# Itration 5: x= 0.656 and f(x) = 0.0003
# Itration 6: x= 0.6561 and f(x) = 0.0
# Itration 7: x= 0.6561 and f(x) = 0.0
# Itration 8: x= 0.6561 and f(x) = 0.0
# Itration 9: x= 0.6561 and f(x) = 0.0
# Itration 10: x= 0.6561 and f(x) = 0.0
# Itration 11: x= 0.6561 and f(x) = 0.0
# Itration 12: x= 0.6561 and f(x) = 0.0
# The value of root is : 0.6561 after 13 Itration
