# %% [markdown]
# <h1 align="center"><strong>Vansh Shah - TIU2141050775</strong></h1>
#
# <h2 align="center"><em>PRACTICAL - 1</em></h2>
#
# <h3 align="center"><strong>Bisection Method</strong></h3>

# %% [markdown]
# # **1**. x<sup>3</sup> + x − 5 = 0, till 5 d.p.

# %%
import math

def f(x):
    return x**3+x-5;

def check():
    i=0;
    while (True):
        j=i+1;

        if ( f(i)*f(j) < 0 ):
            print(f"The root of the given function lies between {(i,j)}");
            bisection(i,j);
            break;

        else:
            i+=1;

def bisection(a,b):
    root=a;
    step=1;

    while ( (b-a) >= tolerance ):
        root=(a+b)/2;
        print(f"Itration {step}: x= {round(root,pre)} and f(x) = {round(f(root),pre)} ")

        if ( f(root) == 0.0 ):
            break;

        if ( f(root)*f(a) < 0 ):
            b=root;

        else:
            a=root;
        step+=1;
    print(f"The value of root is : {round(root,pre)} after {step} Itration")
tolerance = float(input("Enter Tolerance Value:"))
pre = int(input("Enter d.p.: "))
check();
# Out:
# Enter Tolerance Value:0.0000001
# Enter d.p.: 6
# The root of the given function lies between (1, 2)
# Itration 1: x= 1.5 and f(x) = -0.125
# Itration 2: x= 1.75 and f(x) = 2.109375
# Itration 3: x= 1.625 and f(x) = 0.916016
# Itration 4: x= 1.5625 and f(x) = 0.377197
# Itration 5: x= 1.53125 and f(x) = 0.121613
# Itration 6: x= 1.515625 and f(x) = -0.002804
# Itration 7: x= 1.523438 and f(x) = 0.059125
# Itration 8: x= 1.519531 and f(x) = 0.028091
# Itration 9: x= 1.517578 and f(x) = 0.012626
# Itration 10: x= 1.516602 and f(x) = 0.004907
# Itration 11: x= 1.516113 and f(x) = 0.00105
# Itration 12: x= 1.515869 and f(x) = -0.000877
# Itration 13: x= 1.515991 and f(x) = 8.7e-05
# Itration 14: x= 1.51593 and f(x) = -0.000395
# Itration 15: x= 1.515961 and f(x) = -0.000154
# Itration 16: x= 1.515976 and f(x) = -3.4e-05
# Itration 17: x= 1.515984 and f(x) = 2.6e-05
# Itration 18: x= 1.51598 and f(x) = -4e-06
# Itration 19: x= 1.515982 and f(x) = 1.1e-05
# ...

# %% [markdown]
# # **2**. tan(x + 1) = ln(x + 1) + 2, till 6 d.p. (Find the negative root)

# %%
import math

def f(x):
    return math.tan(x+1)-math.log(x+1)/math.log(2.203)+2;

def check():
    i=0;
    while (True):
        #domain for log func is (-1,0) for negative root .
        j=-0.99;

        if ( f(i)*f(j) < 0 ):
            print(f"The root of the given function lies between {(i,j)}");
            bisection(i,j);
            break;

        else:
            i+=1;

def bisection(a,b):
    root=a;
    step=1;
    while ( (b-a) >= tolerance ):
        root=(a+b)/2;
        print(f"Itration {step}: x= {round(root,pre)} and f(x) = {round(f(root),pre)} ")

        if ( f(root) == 0.0 ):
            break;

        if ( f(root)*f(a) < 0 ):
            b=root;

        else:
            a=root;
        step+=1;
    print(f"The value of root is : {round(root,pre)} after {step} Itration")
tolerance = float(input("Enter Tolerance Value:"))
pre = int(input("Enter d.p.: "))
check();
# Out:
# Enter Tolerance Value:0.0000001
# Enter d.p.: 6
# The root of the given function lies between (1, -0.99)
# The value of root is : 1 after 1 Itration

# %% [markdown]
# # **3**. x<sup>3</sup> − 2x − 5 = 0 (positive root)

# %%
import math

def f(x):
    return x**3-2*x-5;

def check():
    i=0;
    while (True):
        j=i+1;

        if ( f(i)*f(j) < 0 ):
            print(f"The root of the given function lies between {(i,j)}");
            bisection(i,j);
            break;

        else:
            i+=1;

def bisection(a,b):
    root=a;
    step=1;

    while ( (b-a) >= tolerance ):
        root=(a+b)/2;
        print(f"Itration {step}: x= {round(root,pre)} and f(x) = {round(f(root),pre)} ")

        if ( f(root) == 0.0 ):
            break;

        if ( f(root)*f(a) < 0 ):
            b=root;

        else:
            a=root;
        step+=1;
    print(f"The value of root is : {round(root,pre)} after {step} Itration")
tolerance = float(input("Enter Tolerance Value:"))
pre = int(input("Enter d.p.: "))
check();
# Out:
# Enter Tolerance Value:0.00001
# Enter d.p.: 4
# The root of the given function lies between (2, 3)
# Itration 1: x= 2.5 and f(x) = 5.625
# Itration 2: x= 2.25 and f(x) = 1.8906
# Itration 3: x= 2.125 and f(x) = 0.3457
# Itration 4: x= 2.0625 and f(x) = -0.3513
# Itration 5: x= 2.0938 and f(x) = -0.0089
# Itration 6: x= 2.1094 and f(x) = 0.1668
# Itration 7: x= 2.1016 and f(x) = 0.0786
# Itration 8: x= 2.0977 and f(x) = 0.0347
# Itration 9: x= 2.0957 and f(x) = 0.0129
# Itration 10: x= 2.0947 and f(x) = 0.002
# Itration 11: x= 2.0942 and f(x) = -0.0035
# Itration 12: x= 2.0945 and f(x) = -0.0008
# Itration 13: x= 2.0946 and f(x) = 0.0006
# Itration 14: x= 2.0945 and f(x) = -0.0001
# Itration 15: x= 2.0946 and f(x) = 0.0003
# Itration 16: x= 2.0946 and f(x) = 0.0001
# Itration 17: x= 2.0946 and f(x) = -0.0
# The value of root is : 2.0946 after 18 Itration

# %% [markdown]
# # **4**. x − e<sup>−x</sup> = 0

# %%
import math

def f(x):
    return x-math.e**(-x);

def check():
    i=0;
    while (True):
        j=i+1;

        if ( f(i)*f(j) < 0 ):
            print(f"The root of the given function lies between {(i,j)}");
            bisection(i,j);
            break;

        else:
            i+=1;

def bisection(a,b):
    root=a;
    step=1;

    while ( (b-a) >= tolerance ):
        root=(a+b)/2;
        print(f"Itration {step}: x= {round(root,pre)} and f(x) = {round(f(root),pre)} ")

        if ( f(root) == 0.0 ):
            break;

        if ( f(root)*f(a) < 0 ):
            b=root;

        else:
            a=root;
        step+=1;
    print(f"The value of root is : {round(root,pre)} after {step} Itration")
tolerance = float(input("Enter Tolerance Value:"))
pre = int(input("Enter d.p.: "))
check();
# Out:
# Enter Tolerance Value:0.00001
# Enter d.p.: 4
# The root of the given function lies between (0, 1)
# Itration 1: x= 0.5 and f(x) = -0.1065
# Itration 2: x= 0.75 and f(x) = 0.2776
# Itration 3: x= 0.625 and f(x) = 0.0897
# Itration 4: x= 0.5625 and f(x) = -0.0073
# Itration 5: x= 0.5938 and f(x) = 0.0415
# Itration 6: x= 0.5781 and f(x) = 0.0172
# Itration 7: x= 0.5703 and f(x) = 0.005
# Itration 8: x= 0.5664 and f(x) = -0.0012
# Itration 9: x= 0.5684 and f(x) = 0.0019
# Itration 10: x= 0.5674 and f(x) = 0.0004
# Itration 11: x= 0.5669 and f(x) = -0.0004
# Itration 12: x= 0.5671 and f(x) = -0.0
# Itration 13: x= 0.5673 and f(x) = 0.0002
# Itration 14: x= 0.5672 and f(x) = 0.0001
# The value of root is : 0.5672 after 15 Itration

# %% [markdown]
# # **5**. cos x − x e<sup>x</sup> = 0

# %%
import math

def f(x):
    return math.cos(x)-x*math.e**(x);

def check():
    i=0;
    while (True):
        j=i+1;

        if ( f(i)*f(j) < 0 ):
            print(f"The root of the given function lies between {(i,j)}");
            bisection(i,j);
            break;

        else:
            i+=1;

def bisection(a,b):
    root=a;
    step=1;

    while ( (b-a) >= tolerance ):
        root=(a+b)/2;
        print(f"Itration {step}: x= {round(root,pre)} and f(x) = {round(f(root),pre)} ")

        if ( f(root) == 0.0 ):
            break;

        if ( f(root)*f(a) < 0 ):
            b=root;

        else:
            a=root;
        step+=1;
    print(f"The value of root is : {round(root,pre)} after {step} Itration")
tolerance = float(input("Enter Tolerance Value:"))
pre = int(input("Enter d.p.: "))
check();
# Out:
# Enter Tolerance Value:0.00001
# Enter d.p.: 4
# The root of the given function lies between (0, 1)
# Itration 1: x= 0.5 and f(x) = 0.0532
# Itration 2: x= 0.75 and f(x) = -0.8561
# Itration 3: x= 0.625 and f(x) = -0.3567
# Itration 4: x= 0.5625 and f(x) = -0.1413
# Itration 5: x= 0.5312 and f(x) = -0.0415
# Itration 6: x= 0.5156 and f(x) = 0.0065
# Itration 7: x= 0.5234 and f(x) = -0.0174
# Itration 8: x= 0.5195 and f(x) = -0.0054
# Itration 9: x= 0.5176 and f(x) = 0.0005
# Itration 10: x= 0.5186 and f(x) = -0.0024
# Itration 11: x= 0.5181 and f(x) = -0.0009
# Itration 12: x= 0.5178 and f(x) = -0.0002
# Itration 13: x= 0.5177 and f(x) = 0.0002
# Itration 14: x= 0.5178 and f(x) = -0.0
# Itration 15: x= 0.5177 and f(x) = 0.0001
# Itration 16: x= 0.5177 and f(x) = 0.0
# Itration 17: x= 0.5178 and f(x) = 0.0
# The value of root is : 0.5178 after 18 Itration
